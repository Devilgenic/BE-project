# %% [markdown]
# # Violence Detection System - Colab Deployment
# Run all cells in order. At the end you'll get a public URL.

# %%
# Step 1: Install ngrok
# !pip install pyngrok -q

# %%
# Step 2: Set your ngrok auth token
# Get free token from: https://dashboard.ngrok.com/get-started/your-authtoken
# Sign up free at ngrok.com, copy your token, paste below
NGROK_AUTH_TOKEN = ""  # <-- PASTE YOUR TOKEN HERE

from pyngrok import ngrok
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# %%
# Step 3: Clone your repo
# !git clone https://github.com/Devilgenic/BE-project.git
# %cd BE-project

# %%
# Step 4: Install dependencies
# !pip install flask flask-socketio simple-websocket opencv-python-headless tensorflow numpy requests playsound3 -q

# %%
# Step 5: Start ngrok tunnel and run app
import os
os.environ['RENDER'] = ''  # Not Render, use normal settings

# Open ngrok tunnel on port 5000
public_url = ngrok.connect(5000)
print("=" * 60)
print(f"PUBLIC URL: {public_url}")
print("=" * 60)
print("Open this URL in your browser!")
print("Browser Cam will work (ngrok provides HTTPS)")
print("Keep this cell running - do NOT stop it")

# %%
# Step 6: Run the Flask app (this cell keeps running)
# !python app.py
